# %%
import pandas as pd

# %%
data=pd.read_csv('Data_set.csv')

# %%
data.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
gender=data['gender']
age=data['age']
df = data[['gender', 'age']]

# %%
count= gender.value_counts()

# %%
count
# Out:
# gender
# Male      25
# Female    15
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=count.index, y=count.values, palette='viridis')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 8))
count.plot.pie(autopct='%1.1f%%', colors=sns.color_palette('viridis', len(count)))
plt.ylabel('')
plt.title('Gender Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=age, y=gender, hue=gender, palette='viridis', s=100, alpha=0.6, edgecolor='w', linewidth=0.5)
plt.xlabel('Age')
plt.ylabel('Gender')
plt.title('Scatter Plot of Gender Distribution by Age')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(gender, bins=len(count), discrete=True)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution - Histogram')
plt.show()
# Out:
# C:\Users\abish_pnsgm5q\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=gender, y=age, data=df, palette='viridis')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Age Distribution by Gender - Box Plot')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='gender', y='age', data=df, palette='viridis')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Age Distribution by Gender - Violin Plot')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(x='gender', y='age', data=df)
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Age Distribution by Gender - Swarm Plot')
plt.show()
# Out:
# C:\Users\abish_pnsgm5q\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abish_pnsgm5q\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abish_pnsgm5q\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(x='gender', y='age', data=df, palette='viridis')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Age Distribution by Gender - Strip Plot')
plt.show()
# Out:
# C:\Users\abish_pnsgm5q\AppData\Local\Temp\ipykernel_17252\3470309376.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(x='gender', y='age', data=df, palette='viridis')
# C:\Users\abish_pnsgm5q\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abish_pnsgm5q\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
g = sns.FacetGrid(df, col="gender", height=6, aspect=1)
g.map(sns.histplot, "age")
g.set_axis_labels("age", "Count")
g.set_titles("Gender")
g.fig.suptitle('Age Distribution by Gender - Facet Grid', y=1.02)
plt.show()
# Out:
# C:\Users\abish_pnsgm5q\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\abish_pnsgm5q\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
